# %%
import matplotlib.font_manager as fm
import pandas as pd

fonts = fm.findSystemFonts()
fna=[]
l1=[]
l2=[]
for font in fonts:
    text=font.strip()
    text=font.split('/')
    fna=fna+[text[-1]]
    l1=l1+[len(text[-1])]
    l2=l2+[len(font)]
print('length of list-fna       =',len(fna))
print('length of list-fonts     =',len(fonts))
print('character length of fna  =',max(l1))
print('character length of fonts=',max(l2))
cl=max(l1)+max(l2)
df=pd.DataFrame({
    'fname': fna,
    'path' : fonts
})
pd.set_option('display.max_rows',len(fna))
pd.set_option('display.max_colwidth',cl)
df=df.sort_values(by='fname')
df
# Out:
# length of list-fna       = 466
# length of list-fonts     = 466
# character length of fna  = 41
# character length of fonts= 76
#                                          fname  \
# 333                               ARIALUNI.TTF
# 187                   AbrilFatface-Regular.otf
# 371                   AbrilFatface-Regular.ttf
# 67              Academy Engraved LET Fonts.ttf
# 140                                Al Nile.ttc
# 214                              Al Tarikh.ttc
# 335                                AlBayan.ttc
# 93                      AmericanTypewriter.ttc
# 441                            Andale Mono.ttf
# 227            Apple Braille Outline 6 Dot.ttf
# 123            Apple Braille Outline 8 Dot.ttf
# 47            Apple Braille Pinpoint 6 Dot.ttf
# 460           Apple Braille Pinpoint 8 Dot.ttf
# 395                          Apple Braille.ttf
# 386                         Apple Chancery.ttf
# 262                      Apple Color Emoji.ttc
# 133                          Apple Symbols.ttf
# 112                            AppleGothic.ttf
# 321                           AppleMyungjo.ttf
# 79                        AppleSDGothicNeo.ttc
# 220                               AquaKana.ttc
# 180                        ArabicUIDisplay.ttc
# 178                           ArabicUIText.ttc
# 352                            Arial Black.ttf
# 58                       Arial Bold Italic.ttf
# 299                             Arial Bold.ttf
# 172                           Arial Italic.ttf
# 129               Arial Narrow Bold Italic.ttf
# 175                      Arial Narrow Bold.ttf
# 224                    Arial Narrow Italic.ttf
# 260                           Arial Narrow.ttf
# 154                     Arial Rounded Bold.ttf
# 139                          Arial Unicode.ttf
# 8                            Arial Unicode.ttf
# 309                                  Arial.ttf
# 21                                 ArialHB.ttc
# 143                                Athelas.ttc
# 445                  Avenir Next Condensed.ttc
# 169                            Avenir Next.ttc
# 464                                 Avenir.ttc
# 51                                Ayuthaya.ttf
# 167                                Baghdad.ttc
# 240                          Baloo-Regular.ttf
# 162                              Bangla MN.ttc
# 394                       Bangla Sangam MN.ttc
# 234                            Baskerville.ttc
# 237                             Bebas Neue.ttf
# 311                         BebasNeue Bold.otf
# 400                         BebasNeue Book.otf
# 152                         BebasNeue Book.ttf
# 332                        BebasNeue Light.otf
# 131                        BebasNeue Light.ttf
# 254                      BebasNeue Regular.otf
# 145                      BebasNeue Regular.ttf
# 327                         BebasNeue Thin.otf
# 68                          BebasNeue Thin.ttf
# 75                                  Beirut.ttc
# 274                              BigCaslon.ttf
# 440                           Bodoni 72 OS.ttc
# 366               Bodoni 72 Smallcaps Book.ttf
# 29                               Bodoni 72.ttc
# 209                       Bodoni Ornaments.ttf
# 389                      Bradley Hand Bold.ttf
# 100                           Brush Script.ttf
# 164                   BungeeInline-Regular.ttf
# 155                            Caveat-Bold.ttf
# 177                         Caveat-Regular.ttf
# 103                             Chalkboard.ttc
# 318                           ChalkboardSE.ttc
# 253                            Chalkduster.ttf
# 463                                Charter.ttc
# 122                         Cinzel-Regular.ttf
# 30                                  Cochin.ttc
# 422                     Comic Sans MS Bold.ttf
# 353                          Comic Sans MS.ttf
# 63                             Copperplate.ttc
# 393                                Corsiva.ttc
# 120                Courier New Bold Italic.ttf
# 207                       Courier New Bold.ttf
# 346                     Courier New Italic.ttf
# 432                            Courier New.ttf
# 252                     DIN Alternate Bold.ttf
# 195                     DIN Condensed Bold.ttf
# 202                               Damascus.ttc
# 443                          DecoTypeNaskh.ttc
# 92                    Devanagari Sangam MN.ttc
# 89                            DevanagariMT.ttc
# 88                                   Didot.ttc
# 334                             Diwan Kufi.ttc
# 28                           Diwan Thuluth.ttf
# 291                            EuphemiaCAS.ttc
# 278                              Exo-Black.otf
# 399                               Exo-Bold.otf
# 459                          Exo-ExtraBold.otf
# 418                         Exo-ExtraLight.otf
# 390                             Exo-Italic.otf
# 54                               Exo-Light.otf
# 276                             Exo-Medium.otf
# 19                             Exo-Regular.otf
# 280                           Exo-SemiBold.otf
# 185                               Exo-Thin.otf
# 108                                  Farah.ttc
# 351                                 Farisi.ttf
# 247                                 Futura.ttc
# 382                                 Galvji.ttc
# 369                               GeezaPro.ttc
# 118                    Georgia Bold Italic.ttf
# 450                           Georgia Bold.ttf
# 12                          Georgia Italic.ttf
# 115                                Georgia.ttf
# 106                               GillSans.ttc
# 109                     Gujarati Sangam MN.ttc
# 65                              GujaratiMT.ttc
# 341                            Gurmukhi MN.ttc
# 151                     Gurmukhi Sangam MN.ttc
# 246                               Gurmukhi.ttf
# 444                              Helvetica.ttc
# 347                          HelveticaNeue.ttc
# 181                             Herculanum.ttf
# 316                       Hiragino Sans GB.ttc
# 20                  Hoefler Text Ornaments.ttf
# 305                           Hoefler Text.ttc
# 182                            IMFePIit28P.ttf
# 60                             IMFePIrm28P.ttf
# 157                          ITFDevanagari.ttc
# 329                                 Impact.ttf
# 98                            InaiMathi-MN.ttc
# 412                        Iowan Old Style.ttc
# 379                                Kailasa.ttc
# 194                             Kannada MN.ttc
# 7                        Kannada Sangam MN.ttc
# 364                                   Kefa.ttc
# 222                               Keyboard.ttf
# 343                               Khmer MN.ttc
# 11                         Khmer Sangam MN.ttf
# 204                        Knewave-Regular.ttf
# 14                                Kohinoor.ttc
# 447                         KohinoorBangla.ttc
# 265                       KohinoorGujarati.ttc
# 150                         KohinoorTelugu.ttc
# 426                                Kokonor.ttf
# 294                              Krungthep.ttf
# 208                         KufiStandardGK.ttc
# 217                       KumarOne-Regular.ttf
# 186                                 Lao MN.ttc
# 406                          Lao Sangam MN.ttf
# 22                              LastResort.otf
# 385                    LeckerliOne-Regular.ttf
# 52                            LucidaGrande.ttc
# 409                               Luminari.ttf
# 336                           Malayalam MN.ttc
# 456                    Malayalam Sangam MN.ttc
# 248                                 Marion.ttc
# 205                             MarkerFelt.ttc
# 331                                  Menlo.ttc
# 433                   Microsoft Sans Serif.ttf
# 130                           Mishafi Gold.ttf
# 356                                Mishafi.ttf
# 235                               Mshtakan.ttc
# 173                             MuktaMahee.ttc
# 289                                   Muna.ttc
# 342                             Myanmar MN.ttc
# 302                      Myanmar Sangam MN.ttc
# 201                              NISC18030.ttf
# 428                                 Nadeem.ttc
# 55                            NewPeninimMT.ttc
# 258                                NewYork.ttf
# 264                          NewYorkItalic.ttf
# 153                             Noteworthy.ttc
# 23                            NotoNastaliq.ttc
# 3                            NotoSans-Bold.ttf
# 191                    NotoSans-BoldItalic.ttf
# 328                        NotoSans-Italic.ttf
# 451                       NotoSans-Regular.ttf
# 301                  NotoSansAdlam-Regular.ttf
# 168                       NotoSansArmenian.ttc
# 99                 NotoSansAvestan-Regular.ttf
# 124                  NotoSansBamum-Regular.ttf
# 230               NotoSansBassaVah-Regular.ttf
# 239                  NotoSansBatak-Regular.ttf
# 304              NotoSansBhaiksuki-Regular.ttf
# 317                 NotoSansBrahmi-Regular.ttf
# 438               NotoSansBuginese-Regular.ttf
# 218                  NotoSansBuhid-Regular.ttf
# 53                  NotoSansCarian-Regular.ttf
# 407      NotoSansCaucasianAlbanian-Regular.ttf
# 255                 NotoSansChakma-Regular.ttf
# 128                   NotoSansCham-Regular.ttf
# 57                  NotoSansCoptic-Regular.ttf
# 138              NotoSansCuneiform-Regular.ttf
# 105                NotoSansCypriot-Regular.ttf
# 355               NotoSansDuployan-Regular.ttf
# 198    NotoSansEgyptianHieroglyphs-Regular.ttf
# 223                NotoSansElbasan-Regular.ttf
# 383             NotoSansGlagolitic-Regular.ttf
# 73                  NotoSansGothic-Regular.ttf
# 1           NotoSansHanifiRohingya-Regular.ttf
# 374                NotoSansHanunoo-Regular.ttf
# 78                  NotoSansHatran-Regular.ttf
# 257        NotoSansImperialAramaic-Regular.ttf
# 188   NotoSansInscriptionalPahlavi-Regular.ttf
# 261  NotoSansInscriptionalParthian-Regular.ttf
# 18                NotoSansJavanese-Regular.otf
# 50                  NotoSansKaithi-Regular.ttf
# 40                         NotoSansKannada.ttc
# 156                NotoSansKayahLi-Regular.ttf
# 427             NotoSansKharoshthi-Regular.ttf
# 146                 NotoSansKhojki-Regular.ttf
# 184              NotoSansKhudawadi-Regular.ttf
# 125                 NotoSansLepcha-Regular.ttf
# 358                  NotoSansLimbu-Regular.ttf
# 190                NotoSansLinearA-Regular.ttf
# 457                NotoSansLinearB-Regular.ttf
# 326                   NotoSansLisu-Regular.ttf
# 454                 NotoSansLycian-Regular.ttf
# 359                 NotoSansLydian-Regular.ttf
# 158               NotoSansMahajani-Regular.ttf
# 5                  NotoSansMandaic-Regular.ttf
# 59              NotoSansManichaean-Regular.ttf
# 270                NotoSansMarchen-Regular.ttf
# 15             NotoSansMeeteiMayek-Regular.ttf
# 367           NotoSansMendeKikakui-Regular.ttf
# 325               NotoSansMeroitic-Regular.ttf
# 42                    NotoSansMiao-Regular.ttf
# 80                    NotoSansModi-Regular.ttf
# 251              NotoSansMongolian-Regular.ttf
# 313                    NotoSansMro-Regular.ttf
# 104                NotoSansMultani-Regular.ttf
# 110                        NotoSansMyanmar.ttc
# 90                     NotoSansNKo-Regular.ttf
# 425              NotoSansNabataean-Regular.ttf
# 84               NotoSansNewTaiLue-Regular.ttf
# 281                   NotoSansNewa-Regular.ttf
# 39                   NotoSansOgham-Regular.ttf
# 149                NotoSansOlChiki-Regular.ttf
# 13            NotoSansOldHungarian-Regular.ttf
# 284              NotoSansOldItalic-Regular.ttf
# 132        NotoSansOldNorthArabian-Regular.ttf
# 24               NotoSansOldPermic-Regular.ttf
# 384             NotoSansOldPersian-Regular.ttf
# 17         NotoSansOldSouthArabian-Regular.ttf
# 465              NotoSansOldTurkic-Regular.ttf
# 95                           NotoSansOriya.ttc
# 337                  NotoSansOsage-Regular.ttf
# 174                NotoSansOsmanya-Regular.ttf
# 203            NotoSansPahawhHmong-Regular.ttf
# 27               NotoSansPalmyrene-Regular.ttf
# 16               NotoSansPauCinHau-Regular.ttf
# 413                NotoSansPhagsPa-Regular.ttf
# 31              NotoSansPhoenician-Regular.ttf
# 461         NotoSansPsalterPahlavi-Regular.ttf
# 82                  NotoSansRejang-Regular.ttf
# 434                  NotoSansRunic-Regular.ttf
# 363              NotoSansSamaritan-Regular.ttf
# 381             NotoSansSaurashtra-Regular.ttf
# 421                NotoSansSharada-Regular.ttf
# 387                NotoSansShavian-Regular.ttf
# 66                 NotoSansSiddham-Regular.ttf
# 86             NotoSansSoraSompeng-Regular.ttf
# 259              NotoSansSundanese-Regular.ttf
# 436            NotoSansSylotiNagri-Regular.ttf
# 229                 NotoSansSyriac-Regular.ttf
# 148                NotoSansTagalog-Regular.ttf
# 452               NotoSansTagbanwa-Regular.ttf
# 322                  NotoSansTaiLe-Regular.ttf
# 170                NotoSansTaiTham-Regular.ttf
# 199                NotoSansTaiViet-Regular.ttf
# 378                  NotoSansTakri-Regular.ttf
# 46                  NotoSansThaana-Regular.ttf
# 370               NotoSansTifinagh-Regular.ttf
# 225                NotoSansTirhuta-Regular.ttf
# 70                NotoSansUgaritic-Regular.ttf
# 244                    NotoSansVai-Regular.ttf
# 165                 NotoSansWancho-Regular.ttf
# 296             NotoSansWarangCiti-Regular.ttf
# 236                     NotoSansYi-Regular.ttf
# 292                         NotoSerif-Bold.ttf
# 344                   NotoSerif-BoldItalic.ttf
# 91                        NotoSerif-Italic.ttf
# 141                      NotoSerif-Regular.ttf
# 380                  NotoSerifAhom-Regular.ttf
# 285              NotoSerifBalinese-Regular.ttf
# 340                       NotoSerifMyanmar.ttc
# 36                           OpenSans-Bold.ttf
# 206                    OpenSans-BoldItalic.ttf
# 263                     OpenSans-ExtraBold.ttf
# 49                OpenSans-ExtraBoldItalic.ttf
# 200                        OpenSans-Italic.ttf
# 101                         OpenSans-Light.ttf
# 249                   OpenSans-LightItalic.ttf
# 392                       OpenSans-Regular.ttf
# 408                      OpenSans-Semibold.ttf
# 241                OpenSans-SemiboldItalic.ttf
# 62                                  Optima.ttc
# 2                           Orbitron-Light.ttf
# 250                               Oriya MN.ttc
# 25                         Oriya Sangam MN.ttc
# 119                                 PTMono.ttc
# 228                                 PTSans.ttc
# 135                                PTSerif.ttc
# 373                         PTSerifCaption.ttc
# 415                       Pacifico-Regular.ttf
# 127                               Palatino.ttc
# 6                                  Papyrus.ttc
# 83                          PartyLET-plain.ttf
# 192                       PatuaOne-Regular.ttf
# 286              PetitFormalScript-Regular.ttf
# 403                              Phosphate.ttc
# 256                               PingFang.ttc
# 193                    PlantagenetCherokee.ttf
# 368                   PressStart2P-Regular.ttf
# 136                         Quicksand-Bold.otf
# 48                    Quicksand-BoldItalic.otf
# 33                        Quicksand-Italic.otf
# 417                        Quicksand-Light.otf
# 449                  Quicksand-LightItalic.otf
# 279                      Quicksand-Regular.otf
# 43                                 Raanana.ttc
# 290                          Raleway-Black.ttf
# 211                    Raleway-BlackItalic.ttf
# 121                           Raleway-Bold.ttf
# 97                      Raleway-BoldItalic.ttf
# 376                      Raleway-ExtraBold.ttf
# 0                  Raleway-ExtraBoldItalic.ttf
# 210                     Raleway-ExtraLight.ttf
# 226               Raleway-ExtraLightItalic.ttf
# 405                         Raleway-Italic.ttf
# 111                          Raleway-Light.ttf
# 183                    Raleway-LightItalic.ttf
# 69                          Raleway-Medium.ttf
# 37                    Raleway-MediumItalic.ttf
# 455                        Raleway-Regular.ttf
# 221                       Raleway-SemiBold.ttf
# 320                 Raleway-SemiBoldItalic.ttf
# 266                           Raleway-Thin.ttf
# 398                             Ricty-Bold.ttf
# 423                             Ricty-Bold.ttf
# 81                           Ricty-Regular.ttf
# 287                          Ricty-Regular.ttf
# 10                       RictyDiscord-Bold.ttf
# 41                       RictyDiscord-Bold.ttf
# 446                   RictyDiscord-Regular.ttf
# 372                   RictyDiscord-Regular.ttf
# 315                           Roboto-Black.ttf
# 35                      Roboto-BlackItalic.ttf
# 437                            Roboto-Bold.ttf
# 9                        Roboto-BoldItalic.ttf
# 272                          Roboto-Italic.ttf
# 231                           Roboto-Light.ttf
# 269                     Roboto-LightItalic.ttf
# 402                          Roboto-Medium.ttf
# 303                    Roboto-MediumItalic.ttf
# 102                         Roboto-Regular.ttf
# 216                            Roboto-Thin.ttf
# 273                      Roboto-ThinItalic.ttf
# 4                          RobotoSlab-Bold.ttf
# 338                       RobotoSlab-Light.ttf
# 377                     RobotoSlab-Regular.ttf
# 242                        RobotoSlab-Thin.ttf
# 345                               Rockwell.ttc
# 312                       RussoOne-Regular.ttf
# 215                              SFCompact.ttf
# 233                        SFCompactItalic.ttf
# 44                        SFCompactRounded.ttf
# 430                                   SFNS.ttf
# 375                             SFNSItalic.ttf
# 330                               SFNSMono.ttf
# 306                         SFNSMonoItalic.ttf
# 45                             SFNSRounded.ttf
# 307                          STHeiti Light.ttc
# 297                         STHeiti Medium.ttc
# 161                            STIXGeneral.otf
# 85                          STIXGeneralBol.otf
# 354                      STIXGeneralBolIta.otf
# 159                      STIXGeneralItalic.otf
# 76                             STIXIntDBol.otf
# 397                            STIXIntDReg.otf
# 357                           STIXIntSmBol.otf
# 348                           STIXIntSmReg.otf
# 462                           STIXIntUpBol.otf
# 416                          STIXIntUpDBol.otf
# 245                          STIXIntUpDReg.otf
# 160                           STIXIntUpReg.otf
# 171                         STIXIntUpSmBol.otf
# 323                         STIXIntUpSmReg.otf
# 56                              STIXNonUni.otf
# 300                          STIXNonUniBol.otf
# 282                       STIXNonUniBolIta.otf
# 349                          STIXNonUniIta.otf
# 277                      STIXSizFiveSymReg.otf
# 117                      STIXSizFourSymBol.otf
# 411                      STIXSizFourSymReg.otf
# 442                       STIXSizOneSymBol.otf
# 61                        STIXSizOneSymReg.otf
# 308                     STIXSizThreeSymBol.otf
# 293                     STIXSizThreeSymReg.otf
# 96                        STIXSizTwoSymBol.otf
# 213                       STIXSizTwoSymReg.otf
# 388                                STIXVar.otf
# 144                             STIXVarBol.otf
# 134                     Sacramento-Regular.ttf
# 414                                   Sana.ttc
# 147                                  Sathu.ttf
# 126                             Savoye LET.ttc
# 94                                 Seravek.ttc
# 396                               Shree714.ttc
# 324                            SignPainter.ttc
# 71                                   Silom.ttf
# 268                             Sinhala MN.ttc
# 219                      Sinhala Sangam MN.ttc
# 362                                   Skia.ttf
# 435                         SnellRoundhand.ttc
# 319                                 Songti.ttc
# 439                SourceHanCodeJP-Regular.otf
# 419                    SourceHanSerif-Bold.otf
# 212                 SourceHanSerif-Regular.otf
# 114                           SukhumvitSet.ttc
# 429                         SuperClarendon.ttc
# 361                                 Symbol.ttf
# 453                            Tahoma Bold.ttf
# 113                                 Tahoma.ttf
# 34                                Tamil MN.ttc
# 404                        Tamil Sangam MN.ttc
# 72                               Telugu MN.ttc
# 295                       Telugu Sangam MN.ttc
# 271                               Thonburi.ttc
# 267            Times New Roman Bold Italic.ttf
# 360                   Times New Roman Bold.ttf
# 38                  Times New Roman Italic.ttf
# 176                        Times New Roman.ttf
# 142                                  Times.ttc
# 74                             Trattatello.ttf
# 424               Trebuchet MS Bold Italic.ttf
# 179                      Trebuchet MS Bold.ttf
# 339                    Trebuchet MS Italic.ttf
# 283                           Trebuchet MS.ttf
# 275                                  Ultra.ttf
# 64                      VampiroOne-Regular.ttf
# 410                     VastShadow-Regular.ttf
# 26                     Verdana Bold Italic.ttf
# 310                           Verdana Bold.ttf
# 166                         Verdana Italic.ttf
# 77                                 Verdana.ttf
# 32                                  Waseem.ttc
# 107                               Webdings.ttf
# 87                             Wingdings 2.ttf
# 391                            Wingdings 3.ttf
# 232                              Wingdings.ttf
# 401                     Yellowtail-Regular.ttf
# 116                           ZapfDingbats.ttf
# 137                                Zapfino.ttf
# 314                                 ipaexg.ttf
# 365                                 ipaexm.ttf
# 350                            roguehero3d.ttf
# 163                       ヒラギノ丸ゴ ProN W4.ttc
# 197                           ヒラギノ明朝 ProN.ttc
# 189                         ヒラギノ角ゴシック W0.ttc
# 420                         ヒラギノ角ゴシック W1.ttc
# 298                         ヒラギノ角ゴシック W2.ttc
# 288                         ヒラギノ角ゴシック W3.ttc
# 196                         ヒラギノ角ゴシック W4.ttc
# 243                         ヒラギノ角ゴシック W5.ttc
# 448                         ヒラギノ角ゴシック W6.ttc
# 238                         ヒラギノ角ゴシック W7.ttc
# 458                         ヒラギノ角ゴシック W8.ttc
# 431                         ヒラギノ角ゴシック W9.ttc
#
#                                                                              path
# 333                                    /Users/tsuyoshi/Library/Fonts/ARIALUNI.TTF
# 187                        /Users/tsuyoshi/Library/Fonts/AbrilFatface-Regular.otf
# 371                        /Users/tsuyoshi/Library/Fonts/AbrilFatface-Regular.ttf
# 67              /System/Library/Fonts/Supplemental/Academy Engraved LET Fonts.ttf
# 140                                /System/Library/Fonts/Supplemental/Al Nile.ttc
# 214                              /System/Library/Fonts/Supplemental/Al Tarikh.ttc
# 335                                /System/Library/Fonts/Supplemental/AlBayan.ttc
# 93                      /System/Library/Fonts/Supplemental/AmericanTypewriter.ttc
# 441                            /System/Library/Fonts/Supplemental/Andale Mono.ttf
# 227                         /System/Library/Fonts/Apple Braille Outline 6 Dot.ttf
# 123                         /System/Library/Fonts/Apple Braille Outline 8 Dot.ttf
# 47                         /System/Library/Fonts/Apple Braille Pinpoint 6 Dot.ttf
# 460                        /System/Library/Fonts/Apple Braille Pinpoint 8 Dot.ttf
# 395                                       /System/Library/Fonts/Apple Braille.ttf
# 386                         /System/Library/Fonts/Supplemental/Apple Chancery.ttf
# 262                                   /System/Library/Fonts/Apple Color Emoji.ttc
# 133                                       /System/Library/Fonts/Apple Symbols.ttf
# 112                            /System/Library/Fonts/Supplemental/AppleGothic.ttf
# 321                           /System/Library/Fonts/Supplemental/AppleMyungjo.ttf
# 79                                     /System/Library/Fonts/AppleSDGothicNeo.ttc
# 220                                            /System/Library/Fonts/AquaKana.ttc
# 180                                     /System/Library/Fonts/ArabicUIDisplay.ttc
# 178                                        /System/Library/Fonts/ArabicUIText.ttc
# 352                            /System/Library/Fonts/Supplemental/Arial Black.ttf
# 58                       /System/Library/Fonts/Supplemental/Arial Bold Italic.ttf
# 299                             /System/Library/Fonts/Supplemental/Arial Bold.ttf
# 172                           /System/Library/Fonts/Supplemental/Arial Italic.ttf
# 129               /System/Library/Fonts/Supplemental/Arial Narrow Bold Italic.ttf
# 175                      /System/Library/Fonts/Supplemental/Arial Narrow Bold.ttf
# 224                    /System/Library/Fonts/Supplemental/Arial Narrow Italic.ttf
# 260                           /System/Library/Fonts/Supplemental/Arial Narrow.ttf
# 154                     /System/Library/Fonts/Supplemental/Arial Rounded Bold.ttf
# 139                                              /Library/Fonts/Arial Unicode.ttf
# 8                            /System/Library/Fonts/Supplemental/Arial Unicode.ttf
# 309                                  /System/Library/Fonts/Supplemental/Arial.ttf
# 21                                              /System/Library/Fonts/ArialHB.ttc
# 143                                /System/Library/Fonts/Supplemental/Athelas.ttc
# 445                               /System/Library/Fonts/Avenir Next Condensed.ttc
# 169                                         /System/Library/Fonts/Avenir Next.ttc
# 464                                              /System/Library/Fonts/Avenir.ttc
# 51                                /System/Library/Fonts/Supplemental/Ayuthaya.ttf
# 167                                /System/Library/Fonts/Supplemental/Baghdad.ttc
# 240                               /Users/tsuyoshi/Library/Fonts/Baloo-Regular.ttf
# 162                              /System/Library/Fonts/Supplemental/Bangla MN.ttc
# 394                       /System/Library/Fonts/Supplemental/Bangla Sangam MN.ttc
# 234                            /System/Library/Fonts/Supplemental/Baskerville.ttc
# 237                                  /Users/tsuyoshi/Library/Fonts/Bebas Neue.ttf
# 311                              /Users/tsuyoshi/Library/Fonts/BebasNeue Bold.otf
# 400                              /Users/tsuyoshi/Library/Fonts/BebasNeue Book.otf
# 152                              /Users/tsuyoshi/Library/Fonts/BebasNeue Book.ttf
# 332                             /Users/tsuyoshi/Library/Fonts/BebasNeue Light.otf
# 131                             /Users/tsuyoshi/Library/Fonts/BebasNeue Light.ttf
# 254                           /Users/tsuyoshi/Library/Fonts/BebasNeue Regular.otf
# 145                           /Users/tsuyoshi/Library/Fonts/BebasNeue Regular.ttf
# 327                              /Users/tsuyoshi/Library/Fonts/BebasNeue Thin.otf
# 68                               /Users/tsuyoshi/Library/Fonts/BebasNeue Thin.ttf
# 75                                  /System/Library/Fonts/Supplemental/Beirut.ttc
# 274                              /System/Library/Fonts/Supplemental/BigCaslon.ttf
# 440                           /System/Library/Fonts/Supplemental/Bodoni 72 OS.ttc
# 366               /System/Library/Fonts/Supplemental/Bodoni 72 Smallcaps Book.ttf
# 29                               /System/Library/Fonts/Supplemental/Bodoni 72.ttc
# 209                       /System/Library/Fonts/Supplemental/Bodoni Ornaments.ttf
# 389                      /System/Library/Fonts/Supplemental/Bradley Hand Bold.ttf
# 100                           /System/Library/Fonts/Supplemental/Brush Script.ttf
# 164                        /Users/tsuyoshi/Library/Fonts/BungeeInline-Regular.ttf
# 155                                 /Users/tsuyoshi/Library/Fonts/Caveat-Bold.ttf
# 177                              /Users/tsuyoshi/Library/Fonts/Caveat-Regular.ttf
# 103                             /System/Library/Fonts/Supplemental/Chalkboard.ttc
# 318                           /System/Library/Fonts/Supplemental/ChalkboardSE.ttc
# 253                            /System/Library/Fonts/Supplemental/Chalkduster.ttf
# 463                                /System/Library/Fonts/Supplemental/Charter.ttc
# 122                              /Users/tsuyoshi/Library/Fonts/Cinzel-Regular.ttf
# 30                                  /System/Library/Fonts/Supplemental/Cochin.ttc
# 422                     /System/Library/Fonts/Supplemental/Comic Sans MS Bold.ttf
# 353                          /System/Library/Fonts/Supplemental/Comic Sans MS.ttf
# 63                             /System/Library/Fonts/Supplemental/Copperplate.ttc
# 393                                /System/Library/Fonts/Supplemental/Corsiva.ttc
# 120                /System/Library/Fonts/Supplemental/Courier New Bold Italic.ttf
# 207                       /System/Library/Fonts/Supplemental/Courier New Bold.ttf
# 346                     /System/Library/Fonts/Supplemental/Courier New Italic.ttf
# 432                            /System/Library/Fonts/Supplemental/Courier New.ttf
# 252                     /System/Library/Fonts/Supplemental/DIN Alternate Bold.ttf
# 195                     /System/Library/Fonts/Supplemental/DIN Condensed Bold.ttf
# 202                               /System/Library/Fonts/Supplemental/Damascus.ttc
# 443                          /System/Library/Fonts/Supplemental/DecoTypeNaskh.ttc
# 92                    /System/Library/Fonts/Supplemental/Devanagari Sangam MN.ttc
# 89                            /System/Library/Fonts/Supplemental/DevanagariMT.ttc
# 88                                   /System/Library/Fonts/Supplemental/Didot.ttc
# 334                             /System/Library/Fonts/Supplemental/Diwan Kufi.ttc
# 28                           /System/Library/Fonts/Supplemental/Diwan Thuluth.ttf
# 291                            /System/Library/Fonts/Supplemental/EuphemiaCAS.ttc
# 278                                   /Users/tsuyoshi/Library/Fonts/Exo-Black.otf
# 399                                    /Users/tsuyoshi/Library/Fonts/Exo-Bold.otf
# 459                               /Users/tsuyoshi/Library/Fonts/Exo-ExtraBold.otf
# 418                              /Users/tsuyoshi/Library/Fonts/Exo-ExtraLight.otf
# 390                                  /Users/tsuyoshi/Library/Fonts/Exo-Italic.otf
# 54                                    /Users/tsuyoshi/Library/Fonts/Exo-Light.otf
# 276                                  /Users/tsuyoshi/Library/Fonts/Exo-Medium.otf
# 19                                  /Users/tsuyoshi/Library/Fonts/Exo-Regular.otf
# 280                                /Users/tsuyoshi/Library/Fonts/Exo-SemiBold.otf
# 185                                    /Users/tsuyoshi/Library/Fonts/Exo-Thin.otf
# 108                                  /System/Library/Fonts/Supplemental/Farah.ttc
# 351                                 /System/Library/Fonts/Supplemental/Farisi.ttf
# 247                                 /System/Library/Fonts/Supplemental/Futura.ttc
# 382                                 /System/Library/Fonts/Supplemental/Galvji.ttc
# 369                                            /System/Library/Fonts/GeezaPro.ttc
# 118                    /System/Library/Fonts/Supplemental/Georgia Bold Italic.ttf
# 450                           /System/Library/Fonts/Supplemental/Georgia Bold.ttf
# 12                          /System/Library/Fonts/Supplemental/Georgia Italic.ttf
# 115                                /System/Library/Fonts/Supplemental/Georgia.ttf
# 106                               /System/Library/Fonts/Supplemental/GillSans.ttc
# 109                     /System/Library/Fonts/Supplemental/Gujarati Sangam MN.ttc
# 65                              /System/Library/Fonts/Supplemental/GujaratiMT.ttc
# 341                            /System/Library/Fonts/Supplemental/Gurmukhi MN.ttc
# 151                     /System/Library/Fonts/Supplemental/Gurmukhi Sangam MN.ttc
# 246                               /System/Library/Fonts/Supplemental/Gurmukhi.ttf
# 444                                           /System/Library/Fonts/Helvetica.ttc
# 347                                       /System/Library/Fonts/HelveticaNeue.ttc
# 181                             /System/Library/Fonts/Supplemental/Herculanum.ttf
# 316                                    /System/Library/Fonts/Hiragino Sans GB.ttc
# 20                  /System/Library/Fonts/Supplemental/Hoefler Text Ornaments.ttf
# 305                           /System/Library/Fonts/Supplemental/Hoefler Text.ttc
# 182                                 /Users/tsuyoshi/Library/Fonts/IMFePIit28P.ttf
# 60                                  /Users/tsuyoshi/Library/Fonts/IMFePIrm28P.ttf
# 157                          /System/Library/Fonts/Supplemental/ITFDevanagari.ttc
# 329                                 /System/Library/Fonts/Supplemental/Impact.ttf
# 98                            /System/Library/Fonts/Supplemental/InaiMathi-MN.ttc
# 412                        /System/Library/Fonts/Supplemental/Iowan Old Style.ttc
# 379                                /System/Library/Fonts/Supplemental/Kailasa.ttc
# 194                             /System/Library/Fonts/Supplemental/Kannada MN.ttc
# 7                        /System/Library/Fonts/Supplemental/Kannada Sangam MN.ttc
# 364                                   /System/Library/Fonts/Supplemental/Kefa.ttc
# 222                                            /System/Library/Fonts/Keyboard.ttf
# 343                               /System/Library/Fonts/Supplemental/Khmer MN.ttc
# 11                         /System/Library/Fonts/Supplemental/Khmer Sangam MN.ttf
# 204                             /Users/tsuyoshi/Library/Fonts/Knewave-Regular.ttf
# 14                                             /System/Library/Fonts/Kohinoor.ttc
# 447                                      /System/Library/Fonts/KohinoorBangla.ttc
# 265                                    /System/Library/Fonts/KohinoorGujarati.ttc
# 150                                      /System/Library/Fonts/KohinoorTelugu.ttc
# 426                                /System/Library/Fonts/Supplemental/Kokonor.ttf
# 294                              /System/Library/Fonts/Supplemental/Krungthep.ttf
# 208                         /System/Library/Fonts/Supplemental/KufiStandardGK.ttc
# 217                            /Users/tsuyoshi/Library/Fonts/KumarOne-Regular.ttf
# 186                                 /System/Library/Fonts/Supplemental/Lao MN.ttc
# 406                          /System/Library/Fonts/Supplemental/Lao Sangam MN.ttf
# 22                                           /System/Library/Fonts/LastResort.otf
# 385                         /Users/tsuyoshi/Library/Fonts/LeckerliOne-Regular.ttf
# 52                                         /System/Library/Fonts/LucidaGrande.ttc
# 409                               /System/Library/Fonts/Supplemental/Luminari.ttf
# 336                           /System/Library/Fonts/Supplemental/Malayalam MN.ttc
# 456                    /System/Library/Fonts/Supplemental/Malayalam Sangam MN.ttc
# 248                                 /System/Library/Fonts/Supplemental/Marion.ttc
# 205                                          /System/Library/Fonts/MarkerFelt.ttc
# 331                                               /System/Library/Fonts/Menlo.ttc
# 433                   /System/Library/Fonts/Supplemental/Microsoft Sans Serif.ttf
# 130                           /System/Library/Fonts/Supplemental/Mishafi Gold.ttf
# 356                                /System/Library/Fonts/Supplemental/Mishafi.ttf
# 235                               /System/Library/Fonts/Supplemental/Mshtakan.ttc
# 173                                          /System/Library/Fonts/MuktaMahee.ttc
# 289                                   /System/Library/Fonts/Supplemental/Muna.ttc
# 342                             /System/Library/Fonts/Supplemental/Myanmar MN.ttc
# 302                      /System/Library/Fonts/Supplemental/Myanmar Sangam MN.ttc
# 201                              /System/Library/Fonts/Supplemental/NISC18030.ttf
# 428                                 /System/Library/Fonts/Supplemental/Nadeem.ttc
# 55                            /System/Library/Fonts/Supplemental/NewPeninimMT.ttc
# 258                                             /System/Library/Fonts/NewYork.ttf
# 264                                       /System/Library/Fonts/NewYorkItalic.ttf
# 153                                          /System/Library/Fonts/Noteworthy.ttc
# 23                                         /System/Library/Fonts/NotoNastaliq.ttc
# 3                                 /Users/tsuyoshi/Library/Fonts/NotoSans-Bold.ttf
# 191                         /Users/tsuyoshi/Library/Fonts/NotoSans-BoldItalic.ttf
# 328                             /Users/tsuyoshi/Library/Fonts/NotoSans-Italic.ttf
# 451                            /Users/tsuyoshi/Library/Fonts/NotoSans-Regular.ttf
# 301                  /System/Library/Fonts/Supplemental/NotoSansAdlam-Regular.ttf
# 168                                    /System/Library/Fonts/NotoSansArmenian.ttc
# 99                 /System/Library/Fonts/Supplemental/NotoSansAvestan-Regular.ttf
# 124                  /System/Library/Fonts/Supplemental/NotoSansBamum-Regular.ttf
# 230               /System/Library/Fonts/Supplemental/NotoSansBassaVah-Regular.ttf
# 239                  /System/Library/Fonts/Supplemental/NotoSansBatak-Regular.ttf
# 304              /System/Library/Fonts/Supplemental/NotoSansBhaiksuki-Regular.ttf
# 317                 /System/Library/Fonts/Supplemental/NotoSansBrahmi-Regular.ttf
# 438               /System/Library/Fonts/Supplemental/NotoSansBuginese-Regular.ttf
# 218                  /System/Library/Fonts/Supplemental/NotoSansBuhid-Regular.ttf
# 53                  /System/Library/Fonts/Supplemental/NotoSansCarian-Regular.ttf
# 407      /System/Library/Fonts/Supplemental/NotoSansCaucasianAlbanian-Regular.ttf
# 255                 /System/Library/Fonts/Supplemental/NotoSansChakma-Regular.ttf
# 128                   /System/Library/Fonts/Supplemental/NotoSansCham-Regular.ttf
# 57                  /System/Library/Fonts/Supplemental/NotoSansCoptic-Regular.ttf
# 138              /System/Library/Fonts/Supplemental/NotoSansCuneiform-Regular.ttf
# 105                /System/Library/Fonts/Supplemental/NotoSansCypriot-Regular.ttf
# 355               /System/Library/Fonts/Supplemental/NotoSansDuployan-Regular.ttf
# 198    /System/Library/Fonts/Supplemental/NotoSansEgyptianHieroglyphs-Regular.ttf
# 223                /System/Library/Fonts/Supplemental/NotoSansElbasan-Regular.ttf
# 383             /System/Library/Fonts/Supplemental/NotoSansGlagolitic-Regular.ttf
# 73                  /System/Library/Fonts/Supplemental/NotoSansGothic-Regular.ttf
# 1           /System/Library/Fonts/Supplemental/NotoSansHanifiRohingya-Regular.ttf
# 374                /System/Library/Fonts/Supplemental/NotoSansHanunoo-Regular.ttf
# 78                  /System/Library/Fonts/Supplemental/NotoSansHatran-Regular.ttf
# 257        /System/Library/Fonts/Supplemental/NotoSansImperialAramaic-Regular.ttf
# 188   /System/Library/Fonts/Supplemental/NotoSansInscriptionalPahlavi-Regular.ttf
# 261  /System/Library/Fonts/Supplemental/NotoSansInscriptionalParthian-Regular.ttf
# 18                /System/Library/Fonts/Supplemental/NotoSansJavanese-Regular.otf
# 50                  /System/Library/Fonts/Supplemental/NotoSansKaithi-Regular.ttf
# 40                                      /System/Library/Fonts/NotoSansKannada.ttc
# 156                /System/Library/Fonts/Supplemental/NotoSansKayahLi-Regular.ttf
# 427             /System/Library/Fonts/Supplemental/NotoSansKharoshthi-Regular.ttf
# 146                 /System/Library/Fonts/Supplemental/NotoSansKhojki-Regular.ttf
# 184              /System/Library/Fonts/Supplemental/NotoSansKhudawadi-Regular.ttf
# 125                 /System/Library/Fonts/Supplemental/NotoSansLepcha-Regular.ttf
# 358                  /System/Library/Fonts/Supplemental/NotoSansLimbu-Regular.ttf
# 190                /System/Library/Fonts/Supplemental/NotoSansLinearA-Regular.ttf
# 457                /System/Library/Fonts/Supplemental/NotoSansLinearB-Regular.ttf
# 326                   /System/Library/Fonts/Supplemental/NotoSansLisu-Regular.ttf
# 454                 /System/Library/Fonts/Supplemental/NotoSansLycian-Regular.ttf
# 359                 /System/Library/Fonts/Supplemental/NotoSansLydian-Regular.ttf
# 158               /System/Library/Fonts/Supplemental/NotoSansMahajani-Regular.ttf
# 5                  /System/Library/Fonts/Supplemental/NotoSansMandaic-Regular.ttf
# 59              /System/Library/Fonts/Supplemental/NotoSansManichaean-Regular.ttf
# 270                /System/Library/Fonts/Supplemental/NotoSansMarchen-Regular.ttf
# 15             /System/Library/Fonts/Supplemental/NotoSansMeeteiMayek-Regular.ttf
# 367           /System/Library/Fonts/Supplemental/NotoSansMendeKikakui-Regular.ttf
# 325               /System/Library/Fonts/Supplemental/NotoSansMeroitic-Regular.ttf
# 42                    /System/Library/Fonts/Supplemental/NotoSansMiao-Regular.ttf
# 80                    /System/Library/Fonts/Supplemental/NotoSansModi-Regular.ttf
# 251              /System/Library/Fonts/Supplemental/NotoSansMongolian-Regular.ttf
# 313                    /System/Library/Fonts/Supplemental/NotoSansMro-Regular.ttf
# 104                /System/Library/Fonts/Supplemental/NotoSansMultani-Regular.ttf
# 110                                     /System/Library/Fonts/NotoSansMyanmar.ttc
# 90                     /System/Library/Fonts/Supplemental/NotoSansNKo-Regular.ttf
# 425              /System/Library/Fonts/Supplemental/NotoSansNabataean-Regular.ttf
# 84               /System/Library/Fonts/Supplemental/NotoSansNewTaiLue-Regular.ttf
# 281                   /System/Library/Fonts/Supplemental/NotoSansNewa-Regular.ttf
# 39                   /System/Library/Fonts/Supplemental/NotoSansOgham-Regular.ttf
# 149                /System/Library/Fonts/Supplemental/NotoSansOlChiki-Regular.ttf
# 13            /System/Library/Fonts/Supplemental/NotoSansOldHungarian-Regular.ttf
# 284              /System/Library/Fonts/Supplemental/NotoSansOldItalic-Regular.ttf
# 132        /System/Library/Fonts/Supplemental/NotoSansOldNorthArabian-Regular.ttf
# 24               /System/Library/Fonts/Supplemental/NotoSansOldPermic-Regular.ttf
# 384             /System/Library/Fonts/Supplemental/NotoSansOldPersian-Regular.ttf
# 17         /System/Library/Fonts/Supplemental/NotoSansOldSouthArabian-Regular.ttf
# 465              /System/Library/Fonts/Supplemental/NotoSansOldTurkic-Regular.ttf
# 95                                        /System/Library/Fonts/NotoSansOriya.ttc
# 337                  /System/Library/Fonts/Supplemental/NotoSansOsage-Regular.ttf
# 174                /System/Library/Fonts/Supplemental/NotoSansOsmanya-Regular.ttf
# 203            /System/Library/Fonts/Supplemental/NotoSansPahawhHmong-Regular.ttf
# 27               /System/Library/Fonts/Supplemental/NotoSansPalmyrene-Regular.ttf
# 16               /System/Library/Fonts/Supplemental/NotoSansPauCinHau-Regular.ttf
# 413                /System/Library/Fonts/Supplemental/NotoSansPhagsPa-Regular.ttf
# 31              /System/Library/Fonts/Supplemental/NotoSansPhoenician-Regular.ttf
# 461         /System/Library/Fonts/Supplemental/NotoSansPsalterPahlavi-Regular.ttf
# 82                  /System/Library/Fonts/Supplemental/NotoSansRejang-Regular.ttf
# 434                  /System/Library/Fonts/Supplemental/NotoSansRunic-Regular.ttf
# 363              /System/Library/Fonts/Supplemental/NotoSansSamaritan-Regular.ttf
# 381             /System/Library/Fonts/Supplemental/NotoSansSaurashtra-Regular.ttf
# 421                /System/Library/Fonts/Supplemental/NotoSansSharada-Regular.ttf
# 387                /System/Library/Fonts/Supplemental/NotoSansShavian-Regular.ttf
# 66                 /System/Library/Fonts/Supplemental/NotoSansSiddham-Regular.ttf
# 86             /System/Library/Fonts/Supplemental/NotoSansSoraSompeng-Regular.ttf
# 259              /System/Library/Fonts/Supplemental/NotoSansSundanese-Regular.ttf
# 436            /System/Library/Fonts/Supplemental/NotoSansSylotiNagri-Regular.ttf
# 229                 /System/Library/Fonts/Supplemental/NotoSansSyriac-Regular.ttf
# 148                /System/Library/Fonts/Supplemental/NotoSansTagalog-Regular.ttf
# 452               /System/Library/Fonts/Supplemental/NotoSansTagbanwa-Regular.ttf
# 322                  /System/Library/Fonts/Supplemental/NotoSansTaiLe-Regular.ttf
# 170                /System/Library/Fonts/Supplemental/NotoSansTaiTham-Regular.ttf
# 199                /System/Library/Fonts/Supplemental/NotoSansTaiViet-Regular.ttf
# 378                  /System/Library/Fonts/Supplemental/NotoSansTakri-Regular.ttf
# 46                  /System/Library/Fonts/Supplemental/NotoSansThaana-Regular.ttf
# 370               /System/Library/Fonts/Supplemental/NotoSansTifinagh-Regular.ttf
# 225                /System/Library/Fonts/Supplemental/NotoSansTirhuta-Regular.ttf
# 70                /System/Library/Fonts/Supplemental/NotoSansUgaritic-Regular.ttf
# 244                    /System/Library/Fonts/Supplemental/NotoSansVai-Regular.ttf
# 165                 /System/Library/Fonts/Supplemental/NotoSansWancho-Regular.ttf
# 296             /System/Library/Fonts/Supplemental/NotoSansWarangCiti-Regular.ttf
# 236                     /System/Library/Fonts/Supplemental/NotoSansYi-Regular.ttf
# 292                              /Users/tsuyoshi/Library/Fonts/NotoSerif-Bold.ttf
# 344                        /Users/tsuyoshi/Library/Fonts/NotoSerif-BoldItalic.ttf
# 91                             /Users/tsuyoshi/Library/Fonts/NotoSerif-Italic.ttf
# 141                           /Users/tsuyoshi/Library/Fonts/NotoSerif-Regular.ttf
# 380                  /System/Library/Fonts/Supplemental/NotoSerifAhom-Regular.ttf
# 285              /System/Library/Fonts/Supplemental/NotoSerifBalinese-Regular.ttf
# 340                                    /System/Library/Fonts/NotoSerifMyanmar.ttc
# 36                                /Users/tsuyoshi/Library/Fonts/OpenSans-Bold.ttf
# 206                         /Users/tsuyoshi/Library/Fonts/OpenSans-BoldItalic.ttf
# 263                          /Users/tsuyoshi/Library/Fonts/OpenSans-ExtraBold.ttf
# 49                     /Users/tsuyoshi/Library/Fonts/OpenSans-ExtraBoldItalic.ttf
# 200                             /Users/tsuyoshi/Library/Fonts/OpenSans-Italic.ttf
# 101                              /Users/tsuyoshi/Library/Fonts/OpenSans-Light.ttf
# 249                        /Users/tsuyoshi/Library/Fonts/OpenSans-LightItalic.ttf
# 392                            /Users/tsuyoshi/Library/Fonts/OpenSans-Regular.ttf
# 408                           /Users/tsuyoshi/Library/Fonts/OpenSans-Semibold.ttf
# 241                     /Users/tsuyoshi/Library/Fonts/OpenSans-SemiboldItalic.ttf
# 62                                               /System/Library/Fonts/Optima.ttc
# 2                                /Users/tsuyoshi/Library/Fonts/Orbitron-Light.ttf
# 250                               /System/Library/Fonts/Supplemental/Oriya MN.ttc
# 25                         /System/Library/Fonts/Supplemental/Oriya Sangam MN.ttc
# 119                                 /System/Library/Fonts/Supplemental/PTMono.ttc
# 228                                 /System/Library/Fonts/Supplemental/PTSans.ttc
# 135                                /System/Library/Fonts/Supplemental/PTSerif.ttc
# 373                         /System/Library/Fonts/Supplemental/PTSerifCaption.ttc
# 415                            /Users/tsuyoshi/Library/Fonts/Pacifico-Regular.ttf
# 127                                            /System/Library/Fonts/Palatino.ttc
# 6                                  /System/Library/Fonts/Supplemental/Papyrus.ttc
# 83                          /System/Library/Fonts/Supplemental/PartyLET-plain.ttf
# 192                            /Users/tsuyoshi/Library/Fonts/PatuaOne-Regular.ttf
# 286                   /Users/tsuyoshi/Library/Fonts/PetitFormalScript-Regular.ttf
# 403                              /System/Library/Fonts/Supplemental/Phosphate.ttc
# 256                                            /System/Library/Fonts/PingFang.ttc
# 193                    /System/Library/Fonts/Supplemental/PlantagenetCherokee.ttf
# 368                        /Users/tsuyoshi/Library/Fonts/PressStart2P-Regular.ttf
# 136                              /Users/tsuyoshi/Library/Fonts/Quicksand-Bold.otf
# 48                         /Users/tsuyoshi/Library/Fonts/Quicksand-BoldItalic.otf
# 33                             /Users/tsuyoshi/Library/Fonts/Quicksand-Italic.otf
# 417                             /Users/tsuyoshi/Library/Fonts/Quicksand-Light.otf
# 449                       /Users/tsuyoshi/Library/Fonts/Quicksand-LightItalic.otf
# 279                           /Users/tsuyoshi/Library/Fonts/Quicksand-Regular.otf
# 43                                 /System/Library/Fonts/Supplemental/Raanana.ttc
# 290                               /Users/tsuyoshi/Library/Fonts/Raleway-Black.ttf
# 211                         /Users/tsuyoshi/Library/Fonts/Raleway-BlackItalic.ttf
# 121                                /Users/tsuyoshi/Library/Fonts/Raleway-Bold.ttf
# 97                           /Users/tsuyoshi/Library/Fonts/Raleway-BoldItalic.ttf
# 376                           /Users/tsuyoshi/Library/Fonts/Raleway-ExtraBold.ttf
# 0                       /Users/tsuyoshi/Library/Fonts/Raleway-ExtraBoldItalic.ttf
# 210                          /Users/tsuyoshi/Library/Fonts/Raleway-ExtraLight.ttf
# 226                    /Users/tsuyoshi/Library/Fonts/Raleway-ExtraLightItalic.ttf
# 405                              /Users/tsuyoshi/Library/Fonts/Raleway-Italic.ttf
# 111                               /Users/tsuyoshi/Library/Fonts/Raleway-Light.ttf
# 183                         /Users/tsuyoshi/Library/Fonts/Raleway-LightItalic.ttf
# 69                               /Users/tsuyoshi/Library/Fonts/Raleway-Medium.ttf
# 37                         /Users/tsuyoshi/Library/Fonts/Raleway-MediumItalic.ttf
# 455                             /Users/tsuyoshi/Library/Fonts/Raleway-Regular.ttf
# 221                            /Users/tsuyoshi/Library/Fonts/Raleway-SemiBold.ttf
# 320                      /Users/tsuyoshi/Library/Fonts/Raleway-SemiBoldItalic.ttf
# 266                                /Users/tsuyoshi/Library/Fonts/Raleway-Thin.ttf
# 398                                         /usr/local/share/fonts/Ricty-Bold.ttf
# 423                                  /Users/tsuyoshi/Library/Fonts/Ricty-Bold.ttf
# 81                                /Users/tsuyoshi/Library/Fonts/Ricty-Regular.ttf
# 287                                      /usr/local/share/fonts/Ricty-Regular.ttf
# 10                            /Users/tsuyoshi/Library/Fonts/RictyDiscord-Bold.ttf
# 41                                   /usr/local/share/fonts/RictyDiscord-Bold.ttf
# 446                               /usr/local/share/fonts/RictyDiscord-Regular.ttf
# 372                        /Users/tsuyoshi/Library/Fonts/RictyDiscord-Regular.ttf
# 315                                /Users/tsuyoshi/Library/Fonts/Roboto-Black.ttf
# 35                           /Users/tsuyoshi/Library/Fonts/Roboto-BlackItalic.ttf
# 437                                 /Users/tsuyoshi/Library/Fonts/Roboto-Bold.ttf
# 9                             /Users/tsuyoshi/Library/Fonts/Roboto-BoldItalic.ttf
# 272                               /Users/tsuyoshi/Library/Fonts/Roboto-Italic.ttf
# 231                                /Users/tsuyoshi/Library/Fonts/Roboto-Light.ttf
# 269                          /Users/tsuyoshi/Library/Fonts/Roboto-LightItalic.ttf
# 402                               /Users/tsuyoshi/Library/Fonts/Roboto-Medium.ttf
# 303                         /Users/tsuyoshi/Library/Fonts/Roboto-MediumItalic.ttf
# 102                              /Users/tsuyoshi/Library/Fonts/Roboto-Regular.ttf
# 216                                 /Users/tsuyoshi/Library/Fonts/Roboto-Thin.ttf
# 273                           /Users/tsuyoshi/Library/Fonts/Roboto-ThinItalic.ttf
# 4                               /Users/tsuyoshi/Library/Fonts/RobotoSlab-Bold.ttf
# 338                            /Users/tsuyoshi/Library/Fonts/RobotoSlab-Light.ttf
# 377                          /Users/tsuyoshi/Library/Fonts/RobotoSlab-Regular.ttf
# 242                             /Users/tsuyoshi/Library/Fonts/RobotoSlab-Thin.ttf
# 345                               /System/Library/Fonts/Supplemental/Rockwell.ttc
# 312                            /Users/tsuyoshi/Library/Fonts/RussoOne-Regular.ttf
# 215                                           /System/Library/Fonts/SFCompact.ttf
# 233                                     /System/Library/Fonts/SFCompactItalic.ttf
# 44                                     /System/Library/Fonts/SFCompactRounded.ttf
# 430                                                /System/Library/Fonts/SFNS.ttf
# 375                                          /System/Library/Fonts/SFNSItalic.ttf
# 330                                            /System/Library/Fonts/SFNSMono.ttf
# 306                                      /System/Library/Fonts/SFNSMonoItalic.ttf
# 45                                          /System/Library/Fonts/SFNSRounded.ttf
# 307                                       /System/Library/Fonts/STHeiti Light.ttc
# 297                                      /System/Library/Fonts/STHeiti Medium.ttc
# 161                            /System/Library/Fonts/Supplemental/STIXGeneral.otf
# 85                          /System/Library/Fonts/Supplemental/STIXGeneralBol.otf
# 354                      /System/Library/Fonts/Supplemental/STIXGeneralBolIta.otf
# 159                      /System/Library/Fonts/Supplemental/STIXGeneralItalic.otf
# 76                             /System/Library/Fonts/Supplemental/STIXIntDBol.otf
# 397                            /System/Library/Fonts/Supplemental/STIXIntDReg.otf
# 357                           /System/Library/Fonts/Supplemental/STIXIntSmBol.otf
# 348                           /System/Library/Fonts/Supplemental/STIXIntSmReg.otf
# 462                           /System/Library/Fonts/Supplemental/STIXIntUpBol.otf
# 416                          /System/Library/Fonts/Supplemental/STIXIntUpDBol.otf
# 245                          /System/Library/Fonts/Supplemental/STIXIntUpDReg.otf
# 160                           /System/Library/Fonts/Supplemental/STIXIntUpReg.otf
# 171                         /System/Library/Fonts/Supplemental/STIXIntUpSmBol.otf
# 323                         /System/Library/Fonts/Supplemental/STIXIntUpSmReg.otf
# 56                              /System/Library/Fonts/Supplemental/STIXNonUni.otf
# 300                          /System/Library/Fonts/Supplemental/STIXNonUniBol.otf
# 282                       /System/Library/Fonts/Supplemental/STIXNonUniBolIta.otf
# 349                          /System/Library/Fonts/Supplemental/STIXNonUniIta.otf
# 277                      /System/Library/Fonts/Supplemental/STIXSizFiveSymReg.otf
# 117                      /System/Library/Fonts/Supplemental/STIXSizFourSymBol.otf
# 411                      /System/Library/Fonts/Supplemental/STIXSizFourSymReg.otf
# 442                       /System/Library/Fonts/Supplemental/STIXSizOneSymBol.otf
# 61                        /System/Library/Fonts/Supplemental/STIXSizOneSymReg.otf
# 308                     /System/Library/Fonts/Supplemental/STIXSizThreeSymBol.otf
# 293                     /System/Library/Fonts/Supplemental/STIXSizThreeSymReg.otf
# 96                        /System/Library/Fonts/Supplemental/STIXSizTwoSymBol.otf
# 213                       /System/Library/Fonts/Supplemental/STIXSizTwoSymReg.otf
# 388                                /System/Library/Fonts/Supplemental/STIXVar.otf
# 144                             /System/Library/Fonts/Supplemental/STIXVarBol.otf
# 134                          /Users/tsuyoshi/Library/Fonts/Sacramento-Regular.ttf
# 414                                   /System/Library/Fonts/Supplemental/Sana.ttc
# 147                                  /System/Library/Fonts/Supplemental/Sathu.ttf
# 126                             /System/Library/Fonts/Supplemental/Savoye LET.ttc
# 94                                 /System/Library/Fonts/Supplemental/Seravek.ttc
# 396                               /System/Library/Fonts/Supplemental/Shree714.ttc
# 324                            /System/Library/Fonts/Supplemental/SignPainter.ttc
# 71                                   /System/Library/Fonts/Supplemental/Silom.ttf
# 268                             /System/Library/Fonts/Supplemental/Sinhala MN.ttc
# 219                      /System/Library/Fonts/Supplemental/Sinhala Sangam MN.ttc
# 362                                   /System/Library/Fonts/Supplemental/Skia.ttf
# 435                         /System/Library/Fonts/Supplemental/SnellRoundhand.ttc
# 319                                 /System/Library/Fonts/Supplemental/Songti.ttc
# 439                     /Users/tsuyoshi/Library/Fonts/SourceHanCodeJP-Regular.otf
# 419                         /Users/tsuyoshi/Library/Fonts/SourceHanSerif-Bold.otf
# 212                      /Users/tsuyoshi/Library/Fonts/SourceHanSerif-Regular.otf
# 114                           /System/Library/Fonts/Supplemental/SukhumvitSet.ttc
# 429                         /System/Library/Fonts/Supplemental/SuperClarendon.ttc
# 361                                              /System/Library/Fonts/Symbol.ttf
# 453                            /System/Library/Fonts/Supplemental/Tahoma Bold.ttf
# 113                                 /System/Library/Fonts/Supplemental/Tahoma.ttf
# 34                                /System/Library/Fonts/Supplemental/Tamil MN.ttc
# 404                        /System/Library/Fonts/Supplemental/Tamil Sangam MN.ttc
# 72                               /System/Library/Fonts/Supplemental/Telugu MN.ttc
# 295                       /System/Library/Fonts/Supplemental/Telugu Sangam MN.ttc
# 271                                            /System/Library/Fonts/Thonburi.ttc
# 267            /System/Library/Fonts/Supplemental/Times New Roman Bold Italic.ttf
# 360                   /System/Library/Fonts/Supplemental/Times New Roman Bold.ttf
# 38                  /System/Library/Fonts/Supplemental/Times New Roman Italic.ttf
# 176                        /System/Library/Fonts/Supplemental/Times New Roman.ttf
# 142                                               /System/Library/Fonts/Times.ttc
# 74                             /System/Library/Fonts/Supplemental/Trattatello.ttf
# 424               /System/Library/Fonts/Supplemental/Trebuchet MS Bold Italic.ttf
# 179                      /System/Library/Fonts/Supplemental/Trebuchet MS Bold.ttf
# 339                    /System/Library/Fonts/Supplemental/Trebuchet MS Italic.ttf
# 283                           /System/Library/Fonts/Supplemental/Trebuchet MS.ttf
# 275                                       /Users/tsuyoshi/Library/Fonts/Ultra.ttf
# 64                           /Users/tsuyoshi/Library/Fonts/VampiroOne-Regular.ttf
# 410                          /Users/tsuyoshi/Library/Fonts/VastShadow-Regular.ttf
# 26                     /System/Library/Fonts/Supplemental/Verdana Bold Italic.ttf
# 310                           /System/Library/Fonts/Supplemental/Verdana Bold.ttf
# 166                         /System/Library/Fonts/Supplemental/Verdana Italic.ttf
# 77                                 /System/Library/Fonts/Supplemental/Verdana.ttf
# 32                                  /System/Library/Fonts/Supplemental/Waseem.ttc
# 107                               /System/Library/Fonts/Supplemental/Webdings.ttf
# 87                             /System/Library/Fonts/Supplemental/Wingdings 2.ttf
# 391                            /System/Library/Fonts/Supplemental/Wingdings 3.ttf
# 232                              /System/Library/Fonts/Supplemental/Wingdings.ttf
# 401                          /Users/tsuyoshi/Library/Fonts/Yellowtail-Regular.ttf
# 116                                        /System/Library/Fonts/ZapfDingbats.ttf
# 137                                /System/Library/Fonts/Supplemental/Zapfino.ttf
# 314                                      /Users/tsuyoshi/Library/Fonts/ipaexg.ttf
# 365                                      /Users/tsuyoshi/Library/Fonts/ipaexm.ttf
# 350                                 /Users/tsuyoshi/Library/Fonts/roguehero3d.ttf
# 163                                    /System/Library/Fonts/ヒラギノ丸ゴ ProN W4.ttc
# 197                                        /System/Library/Fonts/ヒラギノ明朝 ProN.ttc
# 189                                      /System/Library/Fonts/ヒラギノ角ゴシック W0.ttc
# 420                                      /System/Library/Fonts/ヒラギノ角ゴシック W1.ttc
# 298                                      /System/Library/Fonts/ヒラギノ角ゴシック W2.ttc
# 288                                      /System/Library/Fonts/ヒラギノ角ゴシック W3.ttc
# 196                                      /System/Library/Fonts/ヒラギノ角ゴシック W4.ttc
# 243                                      /System/Library/Fonts/ヒラギノ角ゴシック W5.ttc
# 448                                      /System/Library/Fonts/ヒラギノ角ゴシック W6.ttc
# 238                                      /System/Library/Fonts/ヒラギノ角ゴシック W7.ttc
# 458                                      /System/Library/Fonts/ヒラギノ角ゴシック W8.ttc
# 431                                      /System/Library/Fonts/ヒラギノ角ゴシック W9.ttc

# %%
import numpy as np
import matplotlib.pyplot as plt
 
plt.rcParams["font.family"] = "Ricty"   # 使用するフォント
plt.rcParams["font.size"] = 20                 # 文字の大きさ

x = np.arange(-5,5,0.1)
y = np.sin(x)
 
plt.title("グラフ")
plt.xlabel("x")
plt.ylabel("y")
 
plt.plot(x, y, label="sin x")
 
plt.legend()
 
plt.tight_layout()  # フォントサイズが大きくなると文字が描画領域からはみ出るので、プロット全体に合わせて描画領域を大きくする。
 
plt.show()

# %%
import japanize_matplotlib

# %%
plt.plot([1, 2, 3, 4])
plt.xlabel('簡単なグラフ')
plt.show()

# %%
import matplotlib
matplotlib.get_cachedir()
matplotlib.matplotlib_fname()
# Out:
# '/Users/tsuyoshi/opt/anaconda3/envs/aiquest/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc'
